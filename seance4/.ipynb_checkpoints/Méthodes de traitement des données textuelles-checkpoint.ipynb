# %%
#! pip install pyensae

# %% [markdown]
# # Récupération des données : connexion à l'API Pocket

# %% [markdown]
# D'abord il faut s'[authentifier](https://getpocket.com/developer/docs/authentication)

# %% [markdown]
# Protocole utilisé ici : [OAUTH2](https://tools.ietf.org/html/rfc6749) (très classique).

# %% [markdown]
# <img src="./screen_oauth2.png"/>

# %% [markdown]
# 6 étapes donc avant d'avoir le droit de récupérer les données. Souvent, il existe une librairie python. C'est notre cas : https://github.com/rakanalh/pocket-api.

# %%
! pip install pocket
# Out:
# Collecting pocket
#   Downloading pocket-0.3.6.zip
# Requirement already satisfied: requests in /home/athean/anaconda3/lib/python3.5/site-packages (from pocket)
# Building wheels for collected packages: pocket
# done
#   Stored in directory: /home/athean/.cache/pip/wheels/a2/18/f6/b62078897287ce7a098f848b34e9b077fff2e8614b215226a6
# Successfully built pocket
# Installing collected packages: pocket
# Successfully installed pocket-0.3.6

# %% [markdown]
# ### Etape 0 : Récupérer un "consumer_key"

# %% [markdown]
# On l'a fait pour vous. Normalement, c'est ici que cela se passe : https://getpocket.com/developer/apps/new

# %%
CONSUMER_KEY = "71238-e0134275725b685b40df1383"

# %% [markdown]
# ### Etape 1 : Obtenir un code d'authorisation => get_request_token

# %%
import pocket
from pocket import Pocket

REDIRECT_URI = "http://localhost:8888/notebooks/M%C3%A9thodes%20de%20traitement%20des%20donn%C3%A9es%20textuelles.ipynb"
REQUEST_TOKEN = Pocket.get_request_token(consumer_key=CONSUMER_KEY, redirect_uri=REDIRECT_URI)
print(request_token)
# Out:
# 00588893-4723-424c-33a1-3bcfd2

# %% [markdown]
# ### Etape 2: Authoriser l'accès

# %%
url = "https://getpocket.com/auth/authorize?request_token={0}&redirect_uri={1}".format(REQUEST_TOKEN, REDIRECT_URI)
print("Aller à l'url : \n" + url)
# Out:
# Aller à l'url :
# https://getpocket.com/auth/authorize?request_token=bc7fc7cb-5b5b-5c54-2181-dc13b4&redirect_uri=http://localhost:8888/notebooks/M%C3%A9thodes%20de%20traitement%20des%20donn%C3%A9es%20textuelles.ipynb

# %%
import sys, os, subprocess

if sys.platform=='win32':
    os.startfile(url)
elif sys.platform=='darwin':
    subprocess.Popen(['open', url])
else:
    try:
        subprocess.Popen(['xdg-open', url])
    except OSError:
        print('Please open a browser on: ' + url)

# %% [markdown]
# ### Etape 3: Récupérer le token d'accès

# %%
USER_CREDENTIALS = Pocket.get_credentials(consumer_key=CONSUMER_KEY, code=REQUEST_TOKEN)
print(USER_CREDENTIALS)
# Out:
# {'username': 'elodie.royant@tagerstreet.com', 'access_token': 'caa5c4fb-9b2c-d9b8-0da9-630e35'}

# %%
ACCESS_TOKEN = user_credentials['access_token']
print(ACCESS_TOKEN)
# Out:
# caa5c4fb-9b2c-d9b8-0da9-630e35

# %% [markdown]
# ### Etape 4: Récupérer les données

# %%
pocket_instance = pocket.Pocket(CONSUMER_KEY, ACCESS_TOKEN)

# %%
pocket_items = pocket_instance.get()

# %%
pocket_items
# Out:
# ({'complete': 1,
#   'error': None,
#   'list': {'1003565100': {'excerpt': "Ionic est un framework qui va vous permettre de créer des applications mobiles en utilisant des technologies Web. Ionic se base pour cela sur d'autres frameworks / technologies qui ont fait leurs preuves.  Avant de pouvoir commencer, il nous faut évidemment commencer par installer l'outil.",
#     'favorite': '0',
#     'given_title': 'Tutoriel Vidéo Apache Cordova Ionic Framework',
#     'given_url': 'https://www.grafikart.fr/tutoriels/cordova/ionic-framework-641',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1003565100',
#     'resolved_id': '1003565100',
#     'resolved_title': 'Tutoriel Vidéo Apache CordovaIonic Framework',
#     'resolved_url': 'https://www.grafikart.fr/tutoriels/cordova/ionic-framework-641',
#     'sort_id': 389,
#     'status': '0',
#     'time_added': '1486852472',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486852480',
#     'word_count': '782'},
#    '1008275819': {'excerpt': 'Home Create Likes () About Add To Chrome Facebook Thanks! Your color scheme will be reviewed by our hunters.',
#     'favorite': '0',
#     'given_title': 'Color Hunt',
#     'given_url': 'http://colorhunt.co/',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '1',
#     'item_id': '1008275819',
#     'resolved_id': '1008275819',
#     'resolved_title': 'Color Hunt',
#     'resolved_url': 'http://www.colorhunt.co',
#     'sort_id': 361,
#     'status': '0',
#     'time_added': '1487151934',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1487151940',
#     'word_count': '26'},
#    '1011618630': {'excerpt': "In recent months, a host of new tools and packages have been announced for working with data at scale in Python. For an excellent and entertaining summary of these, I'd suggest watching Rob Story's Python Data Bikeshed talk from the 2015 PyData Seattle conference.",
#     'favorite': '0',
#     'given_title': 'Out-of-Core Dataframes in Python: Dask and OpenStreetMap',
#     'given_url': 'https://jakevdp.github.io/blog/2015/08/14/out-of-core-dataframes-in-python/',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '0',
#     'item_id': '1011618630',
#     'resolved_id': '1011618630',
#     'resolved_title': 'Out-of-Core Dataframes in Python: Dask and OpenStreetMap',
#     'resolved_url': 'https://jakevdp.github.io/blog/2015/08/14/out-of-core-dataframes-in-python/',
#     'sort_id': 405,
#     'status': '0',
#     'time_added': '1486851267',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486851281',
#     'word_count': '2291'},
#    '1014684096': {'excerpt': 'In this post, I discuss a method for A/B testing using Beta-Binomial Hierarchical models to correct for a common pitfall when testing multiple hypotheses.',
#     'favorite': '0',
#     'given_title': 'A/B Testing with Hierarchical Models in Python',
#     'given_url': 'https://blog.dominodatalab.com/ab-testing-with-hierarchical-models-in-python/',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1014684096',
#     'resolved_id': '1014684096',
#     'resolved_title': 'A/B Testing with Hierarchical Models in Python',
#     'resolved_url': 'https://blog.dominodatalab.com/ab-testing-with-hierarchical-models-in-python/',
#     'sort_id': 291,
#     'status': '0',
#     'time_added': '1495796186',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1495796190',
#     'word_count': '3839'},
#    '1016233829': {'excerpt': "Getting started with the Web is a concise series introducing you to the practicalities of web development. You'll set up the tools you need to construct a simple webpage and publish your own simple code.",
#     'favorite': '0',
#     'given_title': 'Getting started with the Web - Learn web development | MDN',
#     'given_url': 'https://developer.mozilla.org/en-US/docs/Learn/Getting_started_with_the_web',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1016233829',
#     'resolved_id': '1016233829',
#     'resolved_title': 'Getting started with the Web',
#     'resolved_url': 'https://developer.mozilla.org/en-US/docs/Learn/Getting_started_with_the_web',
#     'sort_id': 271,
#     'status': '0',
#     'time_added': '1497952487',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1497952497',
#     'word_count': '557'},
#    '1028949272': {'excerpt': 'Very cool stuff, useful and smart GET IT',
#     'favorite': '0',
#     'given_title': 'Le Wagon UI components',
#     'given_url': 'http://lewagon.github.io/ui-components/#tabs',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '0',
#     'item_id': '1028949272',
#     'resolved_id': '1028949272',
#     'resolved_title': 'Le Wagon UI components',
#     'resolved_url': 'http://lewagon.github.io/ui-components/#tabs',
#     'sort_id': 396,
#     'status': '0',
#     'time_added': '1486851742',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486851757',
#     'word_count': '8'},
#    '1037787031': {'excerpt': 'If this projects helps you, please give us a star!  Thank you for considering using React on Rails.',
#     'favorite': '0',
#     'given_title': 'shakacode/react_on_rails: Integration of React   Webpack   Rails to build U',
#     'given_url': 'https://github.com/shakacode/react_on_rails',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1037787031',
#     'resolved_id': '1037787031',
#     'resolved_title': 'shakacode/react_on_rails',
#     'resolved_url': 'https://github.com/shakacode/react_on_rails',
#     'sort_id': 44,
#     'status': '0',
#     'time_added': '1506675725',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1506675725',
#     'word_count': '5760'},
#    '1038434596': {'excerpt': 'ADD A NEW RESOURCE For a junior ReactJs posted by hugohow 2 Boot any rails app in under a second.',
#     'favorite': '0',
#     'given_title': 'Le Wagon - Alumni',
#     'given_url': 'http://alumni.lewagon.org/',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '1',
#     'item_id': '1038434596',
#     'resolved_id': '1038434596',
#     'resolved_title': 'Le Wagon - Alumni',
#     'resolved_url': 'http://alumni.lewagon.org/',
#     'sort_id': 411,
#     'status': '0',
#     'time_added': '1486850931',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486850946',
#     'word_count': '579'},
#    '1045811499': {'excerpt': '► Beginner? Try this free iTunes App: http://m.onelink.me/a42c31c2► Learn piano songs quick and easy: http://tinyurl.com/flowkey-mariovereh...► Support me on Patreon: http://www.patreon.com/Marioverehrer► Facebook: http://www.facebook.com/Marioverehrer2► Twitter: https://twitter.com/Mariov',
#     'favorite': '0',
#     'given_title': 'Nocturne Opus 9 No. 2 - Frederic Chopin [Piano Tutorial] (Synthesia) - YouT',
#     'given_url': 'https://www.youtube.com/watch?v=sleZ-hzrtRY',
#     'has_image': '1',
#     'has_video': '2',
#     'is_article': '0',
#     'is_index': '0',
#     'item_id': '1045811499',
#     'resolved_id': '1045811499',
#     'resolved_title': 'Nocturne Opus 9 No. 2  - Frederic Chopin [Piano Tutorial] (Synthesia)',
#     'resolved_url': 'https://www.youtube.com/watch?v=sleZ-hzrtRY',
#     'sort_id': 145,
#     'status': '0',
#     'time_added': '1504560982',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1504560982',
#     'word_count': '0'},
#    '1055285491': {'excerpt': 'Like I did in previous articles on the series, I would love to point out that you should probably set up Babel and follow along the examples with either a REPL or the babel-node CLI and a file. That’ll make it so much easier for you to internalize the concepts discussed in the series.',
#     'favorite': '0',
#     'given_title': 'ES6 Promises in Depth',
#     'given_url': 'https://ponyfoo.com/articles/es6-promises-in-depth',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1055285491',
#     'resolved_id': '1055285491',
#     'resolved_title': 'ES6 Promises in Depth',
#     'resolved_url': 'https://ponyfoo.com/articles/es6-promises-in-depth',
#     'sort_id': 117,
#     'status': '0',
#     'time_added': '1505124981',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1505124987',
#     'word_count': '3721'},
#    '1056127688': {'excerpt': 'Delivered by Fastly, Rendered by Rackspace nbviewer GitHub repository.',
#     'favorite': '0',
#     'given_title': 'Jupyter Notebook Viewer',
#     'given_url': 'http://nbviewer.jupyter.org/github/ptwobrussell/Mining-the-Social-Web-2nd-Edition/tree/master/ipynb/',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1056127688',
#     'resolved_id': '1056127688',
#     'resolved_title': 'Jupyter Notebook Viewer',
#     'resolved_url': 'http://nbviewer.jupyter.org/github/ptwobrussell/Mining-the-Social-Web-2nd-Edition/tree/master/ipynb/',
#     'sort_id': 417,
#     'status': '0',
#     'time_added': '1486850040',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486850055',
#     'word_count': '9'},
#    '1057169119': {'excerpt': 'nltk est une librairie python très utile pour manipuler du texte.',
#     'favorite': '0',
#     'given_title': "Introduction à l'analyse de texte avec nltk - Tokenization",
#     'given_url': 'http://blog.fouadhamdi.com/introduction-a-nltk/',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1057169119',
#     'resolved_id': '1057169119',
#     'resolved_title': "Introduction à l'analyse de texte avec nltk - Tokenization",
#     'resolved_url': 'http://blog.fouadhamdi.com/introduction-a-nltk/',
#     'sort_id': 322,
#     'status': '0',
#     'time_added': '1490723912',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1490723927',
#     'word_count': '758'},
#    '1058981102': {'excerpt': 'Mashape allows you to consume and monitor APIs in your Application, giving you a one stop shop for monitoring, payments, and management.',
#     'favorite': '0',
#     'given_title': 'CloudSight API Documentation',
#     'given_url': 'https://market.mashape.com/imagesearcher/camfind#2-image-response',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '1',
#     'item_id': '1058981102',
#     'resolved_id': '1058981102',
#     'resolved_title': 'CamFind API Documentation',
#     'resolved_url': 'https://market.mashape.com/imagesearcher/camfind',
#     'sort_id': 464,
#     'status': '0',
#     'time_added': '1485209727',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486847233',
#     'word_count': '22'},
#    '1064802343': {'excerpt': "In this first article, we're going to set up some basic tools for doing fundamental data science exercises. Our goal is to run machine-learning classification algorithms against large data sets, using Apache Spark and Elasticsearch clusters in the cloud.",
#     'favorite': '0',
#     'given_title': 'Build an Elasticsearch Index with Python—Machine Learning Series, Part 1',
#     'given_url': 'https://qbox.io/blog/building-an-elasticsearch-index-with-python',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1064802343',
#     'resolved_id': '1064802343',
#     'resolved_title': 'Build an Elasticsearch Index with Python—Machine Learning Series, Part 1',
#     'resolved_url': 'https://qbox.io/blog/building-an-elasticsearch-index-with-python',
#     'sort_id': 303,
#     'status': '0',
#     'time_added': '1491495594',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1491495597',
#     'word_count': '2070'},
#    '1068496952': {'excerpt': 'Access to what’s happening across the globe in real time Speed of discovery and speed to broadcast are essential in today’s ever-evolving world of media.',
#     'favorite': '0',
#     'given_title': 'Discovery | Banjo',
#     'given_url': 'http://ban.jo/discovery',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '1',
#     'item_id': '1068496952',
#     'resolved_id': '1068496952',
#     'resolved_title': 'The “Must-Have” Discovery Tool for every Media Professional',
#     'resolved_url': 'http://ban.jo/discovery/',
#     'sort_id': 380,
#     'status': '0',
#     'time_added': '1486852846',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486852851',
#     'word_count': '105'},
#    '1072497525': {'excerpt': 'If you’re reading this post, you’re probably a corpus linguistics fan who is learning to code with Python using an excellent online tutorial called Natural Language Processing with Python (which is also a book you can buy, in case you feel like a bit of a freeloader).',
#     'favorite': '0',
#     'given_title': 'MIKE S. BOYLE — Python NLTK WTF, Chapter 1: Notes on things that...',
#     'given_url': 'http://www.mikesboyle.com/post/117202964694/python-nltk-wtf-chapter-1-notes-on-things-that',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1072497525',
#     'resolved_id': '1072497525',
#     'resolved_title': 'Python NLTK WTF, Chapter 1: Notes on things that don’t work right',
#     'resolved_url': 'http://www.mikesboyle.com/post/117202964694/python-nltk-wtf-chapter-1-notes-on-things-that',
#     'sort_id': 402,
#     'status': '0',
#     'time_added': '1486851477',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486851488',
#     'word_count': '1601'},
#    '1080754176': {'amp_url': 'https://www.pubnub.com/blog/2015-04-30-google-maps-geolocation-tracking-in-realtime-with-javascript/amp/',
#     'excerpt': 'We’ve updated this tutorial with up-to-date SDKs. Check it out here.  Articles about ride-sharing services have blotted every tech blog on the internet. but try doing a quick search on the technology behind these mobile apps.',
#     'favorite': '0',
#     'given_title': 'Google Maps Geolocation Tracking in Realtime with JavaScript | PubNub',
#     'given_url': 'https://www.pubnub.com/blog/2015-04-30-google-maps-geolocation-tracking-in-realtime-with-javascript/',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1080754176',
#     'resolved_id': '1080754176',
#     'resolved_title': 'Google Maps Geolocation Tracking in Realtime with JavaScript',
#     'resolved_url': 'https://www.pubnub.com/blog/2015-04-30-google-maps-geolocation-tracking-in-realtime-with-javascript/',
#     'sort_id': 440,
#     'status': '0',
#     'time_added': '1485902440',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1487857323',
#     'word_count': '811'},
#    '1086798403': {'excerpt': 'A computer would deserve to be called intelligent if it could deceive a human into believing that it was human. Alan Turing.  When I was a child, I read the book The analytical Engine – Computers Past, Present and Future, by Jeremy Bernstein.',
#     'favorite': '0',
#     'given_title': 'The Definitive Guide to Natural Language Processing',
#     'given_url': 'https://blog.monkeylearn.com/the-definitive-guide-to-natural-language-processing/',
#     'has_image': '1',
#     'has_video': '1',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1086798403',
#     'resolved_id': '1086798403',
#     'resolved_title': 'The Definitive Guide to Natural Language Processing',
#     'resolved_url': 'https://blog.monkeylearn.com/the-definitive-guide-to-natural-language-processing/',
#     'sort_id': 425,
#     'status': '0',
#     'time_added': '1486849658',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486849668',
#     'word_count': '4289'},
#    '1087091031': {'excerpt': 'In your terminal, generate SimpleForm Bootstrap config.  Look at your main application.scss file to see how SCSS files are imported.',
#     'favorite': '0',
#     'given_title': 'lewagon/rails-stylesheets: Stylesheets starting kit @LeWagon',
#     'given_url': 'https://github.com/lewagon/rails-stylesheets',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1087091031',
#     'resolved_id': '1087091031',
#     'resolved_title': 'lewagon/rails-stylesheets',
#     'resolved_url': 'https://github.com/lewagon/rails-stylesheets',
#     'sort_id': 369,
#     'status': '0',
#     'time_added': '1486922310',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486922316',
#     'word_count': '213'},
#    '1090331523': {'excerpt': 'I’ve met a fair amount of ADHD computer programmers over the years. A lot of them were fairly successful in their chosen career, but they all had some combination of the same issues all people with attention deficits\xa0face – distractibility, trouble focusing, disorganization and so on.',
#     'favorite': '0',
#     'given_title': '10 Productivity Tips for Programmers with ADHD | ADHDTechies',
#     'given_url': 'http://adhdtechies.com/productivity-for-adhd-programmers/',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1090331523',
#     'resolved_id': '1090331523',
#     'resolved_title': '10 Productivity Tips for Programmers with ADHD',
#     'resolved_url': 'http://adhdtechies.com/productivity-for-adhd-programmers/',
#     'sort_id': 132,
#     'status': '0',
#     'time_added': '1504801208',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1504801208',
#     'word_count': '1577'},
#    '1091695147': {'excerpt': 'Who do you need to take your idea or startup to the next level? Easily find a perfect fit on EquityOwl. No Salaries. No Cash. Just Equity.  Getting started is easy. Simply create an account to post your ideas or offer your expertise to countless entrepreneurs.',
#     'favorite': '0',
#     'given_title': 'EquityOwl - No Cash. No Salaries. Just Equity.',
#     'given_url': 'http://www.equityowl.com/',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '1',
#     'item_id': '1091695147',
#     'resolved_id': '1091695147',
#     'resolved_title': 'EquityOwl - No Cash. No Salaries. Just Equity.',
#     'resolved_url': 'http://www.equityowl.com/',
#     'sort_id': 78,
#     'status': '0',
#     'time_added': '1505944299',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1505944299',
#     'word_count': '268'},
#    '1092282878': {'excerpt': '? Totally updated with the latest best practices in React, ES6, React Router 4 and more. Free update to all 12,555 of you who have already purchased the course. Enjoy!',
#     'favorite': '0',
#     'given_title': 'React For Beginners — The best way to learn React',
#     'given_url': 'https://reactforbeginners.com/',
#     'has_image': '1',
#     'has_video': '1',
#     'is_article': '0',
#     'is_index': '1',
#     'item_id': '1092282878',
#     'resolved_id': '1092282878',
#     'resolved_title': 'React For Beginners',
#     'resolved_url': 'https://reactforbeginners.com',
#     'sort_id': 207,
#     'status': '0',
#     'time_added': '1502124709',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1502124718',
#     'word_count': '1551'},
#    '1099498384': {'excerpt': 'eBook and Screencast Videos Fully updated',
#     'favorite': '0',
#     'given_title': 'Learn Enough Text Editor to Be Dangerous | Learn Enough to Be Dangerous',
#     'given_url': 'https://www.learnenough.com/text-editor-tutorial',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '0',
#     'item_id': '1099498384',
#     'resolved_id': '1103017591',
#     'resolved_title': 'Learn Enough Text Editor to Be Dangerous Michael Hartl',
#     'resolved_url': 'https://www.softcover.io/books/28fdb94f/learn_enough_text_editor',
#     'sort_id': 391,
#     'status': '0',
#     'time_added': '1486852319',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486852325',
#     'word_count': '6'},
#    '1107958074': {'excerpt': '',
#     'favorite': '0',
#     'given_title': 'Home | Mapbox',
#     'given_url': 'https://www.mapbox.com/studio/welcome/',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '1',
#     'item_id': '1107958074',
#     'resolved_id': '1107958074',
#     'resolved_title': 'Mapbox',
#     'resolved_url': 'https://www.mapbox.com/studio/welcome/',
#     'sort_id': 352,
#     'status': '0',
#     'time_added': '1487587010',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1487587020',
#     'word_count': '0'},
#    '1112590968': {'excerpt': "We're really proud of what we've built here, and we hope you'll love it too. Please try out the new WordPress.com and let us know what you think.  For OSX 10.8+, Windows 7+, and Linux.",
#     'favorite': '0',
#     'given_title': 'Introducing the New WordPress.com',
#     'given_url': 'https://developer.wordpress.com/calypso/',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '1',
#     'item_id': '1112590968',
#     'resolved_id': '1112590968',
#     'resolved_title': 'The New WordPress.com',
#     'resolved_url': 'https://developer.wordpress.com/calypso/',
#     'sort_id': 82,
#     'status': '0',
#     'time_added': '1505921519',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1505921526',
#     'word_count': '37'},
#    '1124085481': {'excerpt': 'A quick search on Font Reach reveals that Proxima Nova is used by over 25,000 websites. It’s the main typeface of some of the most popular companies in digital media, including BuzzFeed, Mashable, NBC News, Wired, and\u200a—\u200ayou guessed it\u200a—\u200aMic.',
#     'favorite': '0',
#     'given_title': 'Why Proxima Nova Is Everywhere. – README . MIC – Medium',
#     'given_url': 'https://medium.com/readme-mic/why-proxima-nova-is-everywhere-629282c687a6#.n7883anud',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1124085481',
#     'resolved_id': '1124085481',
#     'resolved_title': 'Why Proxima Nova Is Everywhere.',
#     'resolved_url': 'https://medium.com/readme-mic/why-proxima-nova-is-everywhere-629282c687a6',
#     'sort_id': 354,
#     'status': '0',
#     'time_added': '1487584791',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1487584813',
#     'word_count': '1317'},
#    '1134763357': {'excerpt': 'SAN FRANCISCO, Calif., Dec. 14, 2011 — PayByPhone, a leading international provider of systems for parking and urban mobility payments, today announced one of the largest deployments of near field communications (NFC) payment solutions in the world.',
#     'favorite': '0',
#     'given_title': 'PayByPhone Adds NFC in San Fran',
#     'given_url': 'https://www.paybyphone.com/news/paybyphone-adds-nfc',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1134763357',
#     'resolved_id': '1134763357',
#     'resolved_title': 'PayByPhone Adds NFC in San Fran',
#     'resolved_url': 'https://www.paybyphone.com/news/paybyphone-adds-nfc',
#     'sort_id': 295,
#     'status': '0',
#     'time_added': '1495400601',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1495400610',
#     'word_count': '506'},
#    '1156668216': {'excerpt': '',
#     'favorite': '0',
#     'given_title': 'Google Wants to Fund App Developers for Project Tango Phone | ProgrammableW',
#     'given_url': 'https://www.programmableweb.com/news/google-wants-to-fund-app-developers-project-tango-phone/2016/01/08',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '0',
#     'item_id': '1156668216',
#     'resolved_id': '1156668216',
#     'resolved_title': 'Google Wants to Fund App Developers for Project Tango Phone',
#     'resolved_url': 'http://www.programmableweb.com/news/google-wants-to-fund-app-developers-project-tango-phone/2016/01/08',
#     'sort_id': 447,
#     'status': '0',
#     'time_added': '1485641178',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486835952',
#     'word_count': '0'},
#    '1159772242': {'excerpt': "We're working to make every smartphone a Magic Window into the world. See how a sofa looks in your living room. Know which exit to take when you get off the subway. Play with a virtual cat that jumps on your lap. With a few extra sensors and some software magic, your device understands the world the",
#     'favorite': '0',
#     'given_title': 'Project Tango - Virtual and Augmented Reality for Mobile Phones (Ubiquity D',
#     'given_url': 'https://www.youtube.com/watch?v=CHV9xTGD4Ws',
#     'has_image': '1',
#     'has_video': '2',
#     'is_article': '0',
#     'is_index': '0',
#     'item_id': '1159772242',
#     'resolved_id': '1159772242',
#     'resolved_title': 'Project Tango - Virtual and Augmented Reality for Mobile Phones (Ubiquity Dev Summit 2016)',
#     'resolved_url': 'https://www.youtube.com/watch?v=CHV9xTGD4Ws',
#     'sort_id': 457,
#     'status': '0',
#     'time_added': '1485468668',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486836139',
#     'word_count': '0'},
#    '1162469194': {'excerpt': 'by  for impekable                      keyboard shortcuts: L or F like Z toggle zoom  post comment',
#     'favorite': '0',
#     'given_title': 'Maps UI Kit by Ray Pansoy - Dribbble',
#     'given_url': 'https://dribbble.com/shots/2457200-Maps-UI-Kit',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '0',
#     'item_id': '1162469194',
#     'resolved_id': '1162469194',
#     'resolved_title': 'Maps UI Kit',
#     'resolved_url': 'https://dribbble.com/shots/2457200-Maps-UI-Kit',
#     'sort_id': 358,
#     'status': '0',
#     'time_added': '1487583276',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1487583283',
#     'word_count': '14'},
#    '1176043172': {'amp_url': 'https://www.lesechos.fr/amp/70/1195670.php',
#     'excerpt': 'Le parlement européen parle d’économie du partage, la commission parle d’économie collaborative : si l’Europe n’est même pas d’accord sur le nom à donner à ce qui pousse les chauffeurs de taxi dans la rue, il y aura à faire.',
#     'favorite': '0',
#     'given_title': '',
#     'given_url': 'https://www.lesechos.fr/idees-debats/cercle/cercle-147380-economie-collaborative-ou-economie-du-partage-cherchez-lerreur-1195670.php',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1176043172',
#     'resolved_id': '1176043172',
#     'resolved_title': "Économie collaborative ou économie du partage : cherchez l'erreur",
#     'resolved_url': 'https://www.lesechos.fr/idees-debats/cercle/cercle-147380-economie-collaborative-ou-economie-du-partage-cherchez-lerreur-1195670.php#Xtor=AD-6000',
#     'sort_id': 101,
#     'status': '0',
#     'time_added': '1505420402',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1505420402',
#     'word_count': '1051'},
#    '1184943571': {'excerpt': 'Epic Country-Level A/B Test Proves Open Is Better Than Closed The Soviet Union’s demise set Estonia and Belarus on opposite paths at the same moment in history. 25 years on, the results are clear.',
#     'favorite': '0',
#     'given_title': 'Backchannel',
#     'given_url': 'https://backchannel.com/',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '1',
#     'item_id': '1184943571',
#     'resolved_id': '1184943575',
#     'resolved_title': 'Backchannel — Medium',
#     'resolved_url': 'https://backchannel.com/?gi=f8ef74f3c515',
#     'sort_id': 471,
#     'status': '0',
#     'time_added': '1484746351',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486847137',
#     'word_count': '418'},
#    '1188643551': {'excerpt': '',
#     'favorite': '0',
#     'given_title': '',
#     'given_url': 'http://www.gouvernement.fr/partage/6421-rapport-de-pascal-terrasse-sur-le-developpement-de-l-economie-collaborative',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '0',
#     'item_id': '1188643551',
#     'resolved_id': '1188643551',
#     'resolved_title': "Rapport de Pascal Terrasse sur le développement de l'économie collaborative",
#     'resolved_url': 'http://www.gouvernement.fr/partage/6421-rapport-de-pascal-terrasse-sur-le-developpement-de-l-economie-collaborative',
#     'sort_id': 103,
#     'status': '0',
#     'time_added': '1505419696',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1505419697',
#     'word_count': '0'},
#    '1190930661': {'excerpt': "La start-up OnePark, spécialisée dans la réservation de parking, vient de lever 2,5 millions d'euros auprès de plusieurs investisseurs, dont le transporteur public Keolis (filiale à 70% de la SNCF).",
#     'favorite': '0',
#     'given_title': 'OnePark lève 2,5 millions d’euros et vise 2 000 parkings en Europe | French',
#     'given_url': 'http://www.frenchweb.fr/onepark-leve-25-millions-deuros-et-vise-2-000-parkings-en-europe/227788',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1190930661',
#     'resolved_id': '1190930661',
#     'resolved_title': 'OnePark lève 2,5 millions d’euros et vise 2 000 parkings en Europe',
#     'resolved_url': 'http://www.frenchweb.fr/onepark-leve-25-millions-deuros-et-vise-2-000-parkings-en-europe/227788',
#     'sort_id': 435,
#     'status': '0',
#     'time_added': '1486320522',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486835810',
#     'word_count': '247'},
#    '1194743912': {'excerpt': '',
#     'favorite': '0',
#     'given_title': 'Augmented Reality - Home | Meta Company',
#     'given_url': 'https://www.metavision.com/',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '0',
#     'item_id': '1194743912',
#     'resolved_id': '1194743912',
#     'resolved_title': '',
#     'resolved_url': 'https://www.metavision.com/',
#     'sort_id': 385,
#     'status': '0',
#     'time_added': '1486852651',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486852655',
#     'word_count': '0'},
#    '1194834816': {'excerpt': 'The most common use case for server-side rendering is to handle the initial render when a user (or search engine crawler) first requests our app. When the server receives the request, it renders the required component(s) into an HTML string, and then sends it as a response to the client.',
#     'favorite': '0',
#     'given_title': 'redux/ServerRendering.md at master · reactjs/redux',
#     'given_url': 'https://github.com/reactjs/redux/blob/master/docs/recipes/ServerRendering.md',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1194834816',
#     'resolved_id': '1194834816',
#     'resolved_title': 'redux/ServerRendering.md at master · reactjs/redux · GitHub',
#     'resolved_url': 'https://github.com/reactjs/redux/blob/master/docs/recipes/ServerRendering.md',
#     'sort_id': 189,
#     'status': '0',
#     'time_added': '1502454471',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1502454471',
#     'word_count': '2213'},
#    '1195896267': {'excerpt': 'La sortie en grande pompe du rapport Terrasse signe d’une certaine façon l’entrée de l’économie collaborative sur la scène politique, la vraie. Pourtant, j’avoue avoir de plus en plus de mal à réprimer un sentiment de malaise.',
#     'favorite': '0',
#     'given_title': '',
#     'given_url': 'http://magazine.ouishare.net/fr/2016/02/leconomie-collaborative-cest-fini/',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1195896267',
#     'resolved_id': '1195896267',
#     'resolved_title': 'L’économie collaborative, c’est fini',
#     'resolved_url': 'http://magazine.ouishare.net/fr/2016/02/leconomie-collaborative-cest-fini/',
#     'sort_id': 102,
#     'status': '0',
#     'time_added': '1505419821',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1505419821',
#     'word_count': '1625'},
#    '1197225394': {'excerpt': "Beaucoup ont envie d'entreprendre, mais manquent d'idées viables ou ont du mal à trouver de bons associés.  On réunit pour vous des dizaines de personnes complémentaires et qualifiées.",
#     'favorite': '0',
#     'given_title': '',
#     'given_url': 'https://locomotiv.co/',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '1',
#     'item_id': '1197225394',
#     'resolved_id': '1197225394',
#     'resolved_title': 'Accueil',
#     'resolved_url': 'https://locomotiv.co',
#     'sort_id': 100,
#     'status': '0',
#     'time_added': '1505458866',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1505458871',
#     'word_count': '288'},
#    '1198552481': {'excerpt': 'I recently upgraded to Sublime Text 3 and rather than copy over my old packages, I decided to start fresh. I’m assuming that you already have the Package Control Package Manager installed and you know how to use it. If not, go here: https://packagecontrol.io',
#     'favorite': '0',
#     'given_title': 'Setting Up Sublime Text 3 for ReactJS – Adrian Li – Medium',
#     'given_url': 'https://medium.com/@adrianli/setting-up-sublime-text-3-for-reactjs-3bf6baceb73a',
#     'has_image': '0',
#     'has_video': '1',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1198552481',
#     'resolved_id': '1198552481',
#     'resolved_title': 'Setting Up Sublime Text 3 for\xa0ReactJS',
#     'resolved_url': 'https://medium.com/@adrianli/setting-up-sublime-text-3-for-reactjs-3bf6baceb73a',
#     'sort_id': 76,
#     'status': '0',
#     'time_added': '1505980580',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1505980580',
#     'word_count': '339'},
#    '1207025977': {'excerpt': 'LA PETITE HISTOIRE A quelques mètres de la place de la République (exactement à 1 minute de la sortie du métro n°5), cet Anticafé est le 4ème à ouvrir en région parisienne.',
#     'favorite': '0',
#     'given_title': 'République — Anticafé',
#     'given_url': 'https://www.anticafe.eu/republique',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '1',
#     'item_id': '1207025977',
#     'resolved_id': '1207025977',
#     'resolved_title': 'République',
#     'resolved_url': 'https://www.anticafe.eu/republique/',
#     'sort_id': 268,
#     'status': '0',
#     'time_added': '1498131950',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1498131961',
#     'word_count': '59'},
#    '1213384226': {'excerpt': '',
#     'favorite': '0',
#     'given_title': 'Connexion | MindMeister',
#     'given_url': 'https://www.mindmeister.com/fr/account/login?product=1',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '1',
#     'item_id': '1213384226',
#     'resolved_id': '1213384226',
#     'resolved_title': 'Connexion',
#     'resolved_url': 'https://www.mindmeister.com/fr/account/login?product=1',
#     'sort_id': 278,
#     'status': '0',
#     'time_added': '1496691642',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1496691647',
#     'word_count': '0'},
#    '1214107610': {'amp_url': 'https://mobiforge.com/design-development/service-worker-toolkits-and-libraries/amp',
#     'excerpt': 'Overwhelmed by service workers? Here’s a collection of tools and libraries that will help tame this powerful beast!  Offline-first, fast, with the sw-precache module is the tagline of the Google-built sw-precache library.',
#     'favorite': '0',
#     'given_title': 'Service worker toolkits and libraries - mobiForge',
#     'given_url': 'https://mobiforge.com/design-development/service-worker-toolkits-and-libraries',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1214107610',
#     'resolved_id': '1214107610',
#     'resolved_title': 'Service worker toolkits and libraries',
#     'resolved_url': 'https://mobiforge.com/design-development/service-worker-toolkits-and-libraries',
#     'sort_id': 459,
#     'status': '0',
#     'time_added': '1485462506',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1485462514',
#     'word_count': '852'},
#    '1214913256': {'excerpt': "The web app manifest is a simple JSON file that gives you, the developer, the ability to control how your app appears to the user in areas where they would expect to see apps (for example, a mobile device's home screen), direct what the user can launch, and define its appearance at launch.",
#     'favorite': '0',
#     'given_title': 'The Web App Manifest \xa0|\xa0 Web \xa0|\xa0 Google Developers',
#     'given_url': 'https://developers.google.com/web/fundamentals/engage-and-retain/web-app-manifest/',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1214913256',
#     'resolved_id': '1214913256',
#     'resolved_title': 'The Web App Manifest',
#     'resolved_url': 'https://developers.google.com/web/fundamentals/engage-and-retain/web-app-manifest/',
#     'sort_id': 84,
#     'status': '0',
#     'time_added': '1505835916',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1505835924',
#     'word_count': '1311'},
#    '123076376': {'excerpt': "Les CSS (Cascading Style Sheets) sont un langage permettant de décrire    la restitution de documents HTML et XML à l'écran, sur papier,    vocalement, etc.",
#     'favorite': '0',
#     'given_title': 'CSS3 module: W3C Selectors',
#     'given_url': 'https://www.w3.org/Style/css3-selectors-updates/WD-css3-selectors-20010126.fr.html#selectors',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '0',
#     'item_id': '123076376',
#     'resolved_id': '123076376',
#     'resolved_title': 'Module CSS3 : Sélecteurs W3C',
#     'resolved_url': 'http://www.w3.org/Style/css3-selectors-updates/WD-css3-selectors-20010126.fr.html#selectors',
#     'sort_id': 116,
#     'status': '0',
#     'time_added': '1505145341',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1505145347',
#     'word_count': '10119'},
#    '1233174413': {'excerpt': 'This will take about 30 minutes.  We will be setting up a Ruby on Rails development environment on Ubuntu 16.04 Xenial Xerus.',
#     'favorite': '0',
#     'given_title': 'Setup Ruby On Rails on Ubuntu 16.04 Xenial Xerus - GoRails',
#     'given_url': 'https://gorails.com/setup/ubuntu/16.04',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1233174413',
#     'resolved_id': '1233174413',
#     'resolved_title': 'Setup Ruby On Rails on Ubuntu 16.04 Xenial Xerus',
#     'resolved_url': 'https://gorails.com/setup/ubuntu/16.04',
#     'sort_id': 261,
#     'status': '0',
#     'time_added': '1498224455',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1498224466',
#     'word_count': '1055'},
#    '1234288492': {'excerpt': 'Google Cloud Speech API enables developers to convert audio to text by applying powerful neural network models in an easy to use API. The API recognizes over 80 languages and variants, to support your global user base.',
#     'favorite': '0',
#     'given_title': 'Speech API - Speech Recognition \xa0|\xa0 Google Cloud Platform',
#     'given_url': 'https://cloud.google.com/speech/',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '1',
#     'item_id': '1234288492',
#     'resolved_id': '1234288492',
#     'resolved_title': 'Speech API',
#     'resolved_url': 'https://cloud.google.com/speech/',
#     'sort_id': 438,
#     'status': '0',
#     'time_added': '1486320491',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486835833',
#     'word_count': '92'},
#    '1234364227': {'excerpt': "In this codelab, you learn how to integrate a service worker into an existing application to make the application work offline. The application is called Air Horner. Click the horn and it makes a sound.  First, let's see what the finished sample app looks like (hint: it's amazing).",
#     'favorite': '0',
#     'given_title': 'Adding a Service Worker and Offline into your Web App',
#     'given_url': 'https://codelabs.developers.google.com/codelabs/offline/index.html#7',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '1',
#     'item_id': '1234364227',
#     'resolved_id': '1234364227',
#     'resolved_title': 'Adding a Service Worker and Offline into your Web App',
#     'resolved_url': 'https://codelabs.developers.google.com/codelabs/offline/',
#     'sort_id': 455,
#     'status': '0',
#     'time_added': '1485471049',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1485471060',
#     'word_count': '1794'},
#    '1236980652': {'excerpt': '► Beginner? Try this free iTunes App: http://m.onelink.me/a42c31c2 *► Learn piano songs quick and easy: http://bit.do/flowkey-marioverehrer *► Sheet music: http://goo.gl/waw64S *► Beginner piano: http://goo.gl/CjVDpO * | ► My piano: http://goo.gl/93l8IA * ► Website: http://www.mariovereh',
#     'favorite': '0',
#     'given_title': 'Fantaisie-Impromptu (Opus 66) - Frederic Chopin [Piano Tutorial] (Synthesia',
#     'given_url': 'https://www.youtube.com/watch?v=GtUQzTCp4NA',
#     'has_image': '1',
#     'has_video': '2',
#     'is_article': '0',
#     'is_index': '0',
#     'item_id': '1236980652',
#     'resolved_id': '1236980652',
#     'resolved_title': 'Fantaisie-Impromptu (Opus 66) - Frederic Chopin [Piano Tutorial] (Synthesia)',
#     'resolved_url': 'http://www.youtube.com/watch?v=GtUQzTCp4NA',
#     'sort_id': 146,
#     'status': '0',
#     'time_added': '1504560944',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1504560944',
#     'word_count': '0'},
#    '1240472260': {'amp_url': 'https://blog.rstudio.org/2016/03/29/feather/amp/',
#     'excerpt': 'This past January, we (Hadley and Wes) met and discussed some of the systems challenges facing the Python and R open source communities.',
#     'favorite': '0',
#     'given_title': 'Feather: A Fast On-Disk Format for Data Frames for R and Python, powered by',
#     'given_url': 'https://blog.rstudio.org/2016/03/29/feather/',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1240472260',
#     'resolved_id': '1240472260',
#     'resolved_title': 'Feather: A Fast On-Disk Format for Data Frames for R and Python, powered by Apache Arrow',
#     'resolved_url': 'https://blog.rstudio.org/2016/03/29/feather/',
#     'sort_id': 423,
#     'status': '0',
#     'time_added': '1486849821',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486849830',
#     'word_count': '823'},
#    '1241438028': {'excerpt': "We facilitate parents' life Sign up now",
#     'favorite': '0',
#     'given_title': 'Agenda | 2houses',
#     'given_url': 'https://tools.2houses.com/agenda',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '0',
#     'item_id': '1241438028',
#     'resolved_id': '1241438028',
#     'resolved_title': 'Please log in / 2houses',
#     'resolved_url': 'https://tools.2houses.com/agenda',
#     'sort_id': 444,
#     'status': '0',
#     'time_added': '1485699681',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486835917',
#     'word_count': '7'},
#    '1269754099': {'excerpt': 'Éléments indispensables pour obtenir un aperçu qualitatif de vos contenus sur les réseaux sociaux, nous vous proposons ce tutoriel pour suivre pas à pas le setup des Meta Tags dans une application Rails.',
#     'favorite': '0',
#     'given_title': 'Le Wagon - Le setup des Meta Tags dans Rails',
#     'given_url': 'https://www.lewagon.com/fr/blog/tuto-setup-metatags-rails',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1269754099',
#     'resolved_id': '1269754099',
#     'resolved_title': 'Le setup des Meta Tags dans Rails',
#     'resolved_url': 'https://www.lewagon.com/fr/blog/tuto-setup-metatags-rails',
#     'sort_id': 335,
#     'status': '0',
#     'time_added': '1488389924',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1488389928',
#     'word_count': '910'},
#    '1282843442': {'excerpt': '► Beginner? Try this free iTunes App: http://m.onelink.me/a42c31c2 *► Learn piano songs quick and easy: http://bit.do/flowkey-marioverehrer *► Sheet music: http://goo.gl/v5ohRz *► Beginner piano: http://goo.gl/CjVDpO * | ► My piano: http://goo.gl/93l8IA * ► Website: http://www.mariovereh',
#     'favorite': '0',
#     'given_title': 'Moonlight Sonata (Complete) [Piano Tutorial] (Synthesia) - YouTube',
#     'given_url': 'https://www.youtube.com/watch?v=Hk-K_D8Zz5Q',
#     'has_image': '1',
#     'has_video': '2',
#     'is_article': '0',
#     'is_index': '0',
#     'item_id': '1282843442',
#     'resolved_id': '1282843442',
#     'resolved_title': 'Moonlight Sonata (Complete) [Piano Tutorial] (Synthesia)',
#     'resolved_url': 'https://www.youtube.com/watch?v=Hk-K_D8Zz5Q',
#     'sort_id': 151,
#     'status': '0',
#     'time_added': '1504560475',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1504560475',
#     'word_count': '0'},
#    '1283046845': {'excerpt': 'We believe in the concept of learning by doing. Sublime Tutor takes you methodically from the most basic commands to very advanced ones. All of this happens inside the editor itself.  Number of interesting exercises keep you entertained throughout the course.',
#     'favorite': '0',
#     'given_title': 'Sublime Tutor - An interactive in-editor keyboard shortcuts tutorial for Su',
#     'given_url': 'https://sublimetutor.com/',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '1',
#     'item_id': '1283046845',
#     'resolved_id': '1283046845',
#     'resolved_title': 'Sublime Tutor - A free and interactive, in-editor tutor for Sublime Text 3',
#     'resolved_url': 'https://sublimetutor.com',
#     'sort_id': 18,
#     'status': '0',
#     'time_added': '1507155525',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1507155525',
#     'word_count': '229'},
#    '1283454965': {'excerpt': 'This repository is a tutorial for a first contact with the Sinatra gem, a DSL for quickly creating web applications in Ruby with minimal effort.',
#     'favorite': '0',
#     'given_title': 'GitHub - lewagon/sinatra-101: Tutorial for a sane first contact with Sinatr',
#     'given_url': 'https://github.com/lewagon/sinatra-101#views',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '1283454965',
#     'resolved_id': '1283454965',
#     'resolved_title': 'lewagon/sinatra-101',
#     'resolved_url': 'https://github.com/lewagon/sinatra-101',
#     'sort_id': 397,
#     'status': '0',
#     'time_added': '1486851694',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486851708',
#     'word_count': '1823'},
#    '128883609': {'excerpt': 'Do you use tags to organize content on your site? This plugin will turn your boring tag list into a magical input that turns each tag into a style-able object with its own delete link.  Tags Input handles all the data, your form just sees a comma-delimited list of tags!',
#     'favorite': '0',
#     'given_title': 'XOXCO | jQuery Tags Input',
#     'given_url': 'http://xoxco.com/projects/code/tagsinput/',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '0',
#     'item_id': '128883609',
#     'resolved_id': '128883609',
#     'resolved_title': 'A software product design and development studio',
#     'resolved_url': 'http://xoxco.com/projects/code/tagsinput/',
#     'sort_id': 325,
#     'status': '0',
#     'time_added': '1490647614',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1490647629',
#     'word_count': '50'},
#    '1290529669': {'excerpt': "There is a lot of information on the web about how to use server-side rendering, or SSR, with React. But the question you'll want to answer first is: should I use it?  Server-side rendering is very cool, and a must-have in certain situations, but it comes with drawbacks.",
#     'favorite': '0',
#     'given_title': '',
#     'given_url': 'http://andrewhfarmer.com/server-side-render/',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
# ...
#     'given_url': 'http://www.appcoda.com/instagram-app-parse-swift/',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '897772388',
#     'resolved_id': '897772388',
#     'resolved_title': 'Building an Instagram-Like App with Parse and Swift',
#     'resolved_url': 'http://www.appcoda.com/instagram-app-parse-swift/',
#     'sort_id': 388,
#     'status': '0',
#     'time_added': '1486852512',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486852520',
#     'word_count': '6208'},
#    '920375739': {'excerpt': "After creating a GitHub account, you need to setup your computer so that you can git push. When cloning a project, you chose SSH or HTTPS. I like to clone my projects in SSH as it will use my keys.  Here's a diagram explaining how those keys are used when you want to git push your code.",
#     'favorite': '0',
#     'given_title': 'GitHub public key authentication - Sébastien Saunier',
#     'given_url': 'http://sebastien.saunier.me/blog/2015/05/10/github-public-key-authentication.html',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '920375739',
#     'resolved_id': '920375739',
#     'resolved_title': 'GitHub public key authentication',
#     'resolved_url': 'http://sebastien.saunier.me/blog/2015/05/10/github-public-key-authentication.html',
#     'sort_id': 264,
#     'status': '0',
#     'time_added': '1498162364',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1506690520',
#     'word_count': '304'},
#    '923449667': {'excerpt': 'ARToolKit 6 is a fast and modern open source tracking and recognition SDK which enables computers to see and understand more in the environment around them.',
#     'favorite': '0',
#     'given_title': 'Open Source Augmented Reality SDK | ARToolKit.org',
#     'given_url': 'https://artoolkit.org/',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '1',
#     'item_id': '923449667',
#     'resolved_id': '923449667',
#     'resolved_title': 'What is ARToolKit 6?',
#     'resolved_url': 'http://artoolkit.org/',
#     'sort_id': 381,
#     'status': '0',
#     'time_added': '1486852765',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486852766',
#     'word_count': '105'},
#    '92738558': {'excerpt': 'clockmore-arrownoyes                                                                                                                                                                                                            Copenhagen Wheel review: a bike that makes you feel like a su',
#     'favorite': '0',
#     'given_title': 'The Verge',
#     'given_url': 'http://www.theverge.com/',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '1',
#     'item_id': '92738558',
#     'resolved_id': '92738558',
#     'resolved_title': 'The Verge',
#     'resolved_url': 'https://www.theverge.com/',
#     'sort_id': 475,
#     'status': '0',
#     'time_added': '1484746248',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486846964',
#     'word_count': '19'},
#    '934060680': {'excerpt': 'Bibliographie¶ Livres sur le machine learning Livres sur les algorithmes Livres sur la programmation  High Performance Python, Micha Gorelick, Ian Ozsvald. Le livre est très bien conçu et les exemples sont très clairs.',
#     'favorite': '0',
#     'given_title': 'Python pour un Data Scientist / Economiste — Python dans tous ses états 0.8',
#     'given_url': 'http://www.xavierdupre.fr/app/ensae_teaching_cs/helpsphinx3/td_2a.html',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '934060680',
#     'resolved_id': '934060680',
#     'resolved_title': 'Python pour un Data Scientist / Economiste¶',
#     'resolved_url': 'http://www.xavierdupre.fr/app/ensae_teaching_cs/helpsphinx3/td_2a.html#bibliographie',
#     'sort_id': 127,
#     'status': '0',
#     'time_added': '1504858528',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1504858534',
#     'word_count': '242'},
#    '952475069': {'excerpt': 'Python is a high-level interpreted language, which greatly reduces the time taken to prototyte and develop useful statistical programs. However, the trade-off is that pure Python programs can be orders of magnitude slower than programs in compiled languages such as C/C++ or Forran.',
#     'favorite': '0',
#     'given_title': 'Optimization bake-off — Computational Statistics in Python 0.1 documentatio',
#     'given_url': 'https://people.duke.edu/~ccc14/sta-663/Optimization_Bakeoff.html',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '952475069',
#     'resolved_id': '952475069',
#     'resolved_title': 'Optimization bake-off¶',
#     'resolved_url': 'https://people.duke.edu/~ccc14/sta-663/Optimization_Bakeoff.html',
#     'sort_id': 414,
#     'status': '0',
#     'time_added': '1486850357',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486850370',
#     'word_count': '1698'},
#    '954473465': {'excerpt': 'It happens on the web from time to time that powerful technologies come to exist without the benefit of marketing departments or slick packaging. They linger and grow at the peripheries, becoming old-hat to a tiny group while remaining nearly invisible to everyone else. Until someone names them.',
#     'favorite': '0',
#     'given_title': 'Progressive Web Apps: Escaping Tabs Without Losing Our Soul | Infrequently ',
#     'given_url': 'https://infrequently.org/2015/06/progressive-apps-escaping-tabs-without-losing-our-soul/',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '954473465',
#     'resolved_id': '954473465',
#     'resolved_title': 'Progressive Web Apps: Escaping Tabs Without Losing Our Soul',
#     'resolved_url': 'https://infrequently.org/2015/06/progressive-apps-escaping-tabs-without-losing-our-soul/',
#     'sort_id': 460,
#     'status': '0',
#     'time_added': '1485462320',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1485462348',
#     'word_count': '1059'},
#    '956222891': {'excerpt': "A filled-in box means the the episode draws events directly from the chapter (this doesn't necessarily mean it covers the entire chapter) A dotted box means the episode draws indirectly from the chapter - revealing events that occur off-page, introducing characters, minor details of an event,",
#     'favorite': '0',
#     'given_title': 'Game of Thrones episode chapter coverage',
#     'given_url': 'http://joeltronics.github.io/got-book-show/bookshow.html',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '0',
#     'item_id': '956222891',
#     'resolved_id': '956222891',
#     'resolved_title': 'Game of Thrones episode chapter coverage',
#     'resolved_url': 'http://joeltronics.github.io/got-book-show/bookshow.html',
#     'sort_id': 165,
#     'status': '0',
#     'time_added': '1504386019',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1504386019',
#     'word_count': '166'},
#    '957402029': {'amp_url': 'https://marcobonzanini.com/2015/06/16/mining-twitter-data-with-python-and-js-part-7-geolocation-and-interactive-maps/amp/',
#     'excerpt': 'Geolocation is the process of identifying the geographic location of an object such as a mobile phone or a computer. Twitter allows its users to provide their location when they publish a tweet, in the form of latitude and longitude coordinates.',
#     'favorite': '0',
#     'given_title': 'Mining Twitter Data with Python (and JS) – Part 7: Geolocation and Interact',
#     'given_url': 'https://marcobonzanini.com/2015/06/16/mining-twitter-data-with-python-and-js-part-7-geolocation-and-interactive-maps/',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '957402029',
#     'resolved_id': '957402029',
#     'resolved_title': 'Mining Twitter Data with Python (and JS) – Part 7: Geolocation and Interactive Maps',
#     'resolved_url': 'https://marcobonzanini.com/2015/06/16/mining-twitter-data-with-python-and-js-part-7-geolocation-and-interactive-maps/',
#     'sort_id': 375,
#     'status': '0',
#     'time_added': '1486853265',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486853289',
#     'word_count': '864'},
#    '969693393': {'excerpt': "I create a simple Rails app and deployed it to Heroku. This is my app. I use Cloudflare to manage my DNS records and I try to achieve something like this:  When I go to ordr.my, it's works like I wanted to. But when I go to www.ordr.",
#     'favorite': '0',
#     'given_title': 'dns - How to point naked domain and www to the same Heroku app? - Webmaster',
#     'given_url': 'http://webmasters.stackexchange.com/questions/82689/how-to-point-naked-domain-and-www-to-the-same-heroku-app',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '969693393',
#     'resolved_id': '969693393',
#     'resolved_title': 'How to point naked domain and www to the same Heroku app?',
#     'resolved_url': 'http://webmasters.stackexchange.com/questions/82689/how-to-point-naked-domain-and-www-to-the-same-heroku-app',
#     'sort_id': 333,
#     'status': '0',
#     'time_added': '1489273945',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1489273961',
#     'word_count': '116'},
#    '972455959': {'excerpt': 'Service workers essentially act as proxy servers that sit between web applications, and the browser and network (when available).',
#     'favorite': '0',
#     'given_title': 'Service Worker API - Web APIs | MDN',
#     'given_url': 'https://developer.mozilla.org/en-US/docs/Web/API/Service_Worker_API',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '972455959',
#     'resolved_id': '972455959',
#     'resolved_title': 'Service Worker API',
#     'resolved_url': 'https://developer.mozilla.org/en-US/docs/Web/API/Service_Worker_API',
#     'sort_id': 453,
#     'status': '0',
#     'time_added': '1485471615',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1485471619',
#     'word_count': '1507'},
#    '978185723': {'excerpt': 'As a Rails developer, I learned a lot just from reading Ruby on Rails code. Aware of that experience, I try to look into the internals of other open source projects as well, to see what’s going on there.',
#     'favorite': '0',
#     'given_title': 'Home - React Kung Fu',
#     'given_url': 'http://reactkungfu.com/',
#     'has_image': '1',
#     'has_video': '1',
#     'is_article': '0',
#     'is_index': '1',
#     'item_id': '978185723',
#     'resolved_id': '978185723',
#     'resolved_title': 'Home',
#     'resolved_url': 'http://reactkungfu.com/',
#     'sort_id': 99,
#     'status': '0',
#     'time_added': '1505468048',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1505468055',
#     'word_count': '2880'},
#    '982419639': {'excerpt': 'What is Geocoding? Geocoding is the process of converting addresses (like "1600 Amphitheatre Parkway, Mountain View, CA") into geographic coordinates (like latitude 37.423021 and longitude -122.083739), which you can use to place markers on a map, or position the map.',
#     'favorite': '0',
#     'given_title': "Developer's Guide \xa0|\xa0 Google Maps Geocoding API \xa0|\xa0 Google Developers",
#     'given_url': 'https://developers.google.com/maps/documentation/geocoding/intro',
#     'has_image': '0',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '982419639',
#     'resolved_id': '982419639',
#     'resolved_title': "Developer's Guide",
#     'resolved_url': 'https://developers.google.com/maps/documentation/geocoding/intro',
#     'sort_id': 394,
#     'status': '0',
#     'time_added': '1486852213',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486852222',
#     'word_count': '6670'},
#    '988342741': {'excerpt': 'Get access to all 20 videos and download the exercises!  Join 102,000+ others in learning with Wes Bos!',
#     'favorite': '0',
#     'given_title': 'What The Flexbox?! — A simple 20 video course that will help you master CSS',
#     'given_url': 'https://flexbox.io/',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '1',
#     'item_id': '988342741',
#     'resolved_id': '988342741',
#     'resolved_title': 'What TheFlexBox?!',
#     'resolved_url': 'https://flexbox.io',
#     'sort_id': 195,
#     'status': '0',
#     'time_added': '1502349675',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1502349675',
#     'word_count': '280'},
#    '989290193': {'excerpt': 'Start Here',
#     'favorite': '0',
#     'given_title': 'ECMAScript 6 Tutorial',
#     'given_url': 'http://ccoenraets.github.io/es6-tutorial/',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '0',
#     'item_id': '989290193',
#     'resolved_id': '989290193',
#     'resolved_title': 'ECMAScript 6 Tutorial',
#     'resolved_url': 'http://ccoenraets.github.io/es6-tutorial/',
#     'sort_id': 208,
#     'status': '0',
#     'time_added': '1502118189',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1502118202',
#     'word_count': '2'},
#    '989889299': {'excerpt': 'One of the most commonly asked questions I get asked is how to load JSON documents into Neo4j and although Cypher doesn’t have a ‘LOAD JSON’ command we can still get JSON data into the graph.',
#     'favorite': '0',
#     'given_title': 'Neo4j: Loading JSON documents with Cypher - Mark Needham at Mark Needham',
#     'given_url': 'http://www.markhneedham.com/blog/2015/07/23/neo4j-loading-json-documents-with-cypher/',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '1',
#     'is_index': '0',
#     'item_id': '989889299',
#     'resolved_id': '989889299',
#     'resolved_title': 'Neo4j: Loading JSON documents with Cypher',
#     'resolved_url': 'http://www.markhneedham.com/blog/2015/07/23/neo4j-loading-json-documents-with-cypher/',
#     'sort_id': 386,
#     'status': '0',
#     'time_added': '1486852567',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1486852572',
#     'word_count': '1089'},
#    '992637806': {'excerpt': 'PARC RIVES DE SEINE – Découvrez notre webdoc!  Comment payer son stationnement à Paris? Voies mixtes, voies rotatives, on vous explique tout.',
#     'favorite': '0',
#     'given_title': 'Payer son stationnement – Paris.fr',
#     'given_url': 'http://www.paris.fr/services-et-infos-pratiques/deplacements-et-stationnement/stationnement/payer-son-stationnement-2129#payer-par-application-internet-ou-serveur-vocal-avec-p-mobile_11',
#     'has_image': '1',
#     'has_video': '0',
#     'is_article': '0',
#     'is_index': '0',
#     'item_id': '992637806',
#     'resolved_id': '992637806',
#     'resolved_title': 'Payer son stationnement',
#     'resolved_url': 'https://www.paris.fr/services-et-infos-pratiques/deplacements-et-stationnement/stationnement/payer-son-stationnement-2129',
#     'sort_id': 296,
#     'status': '0',
#     'time_added': '1495400440',
#     'time_favorited': '0',
#     'time_read': '0',
#     'time_updated': '1495400446',
#     'word_count': '2881'}},
#   'search_meta': {'search_type': 'normal'},
#   'since': 1507393058,
#   'status': 1},
#  {'Expires': 'Thu, 19 Nov 1981 08:52:00 GMT', 'Date': 'Sat, 07 Oct 2017 16:17:38 GMT', 'X-Limit-Key-Reset': '3600', 'Set-Cookie': 'PHPSESSID=pdlh2hovcvsplbji7gi965tk85; path=/', 'P3P': 'policyref="/w3c/p3p.xml", CP="ALL CURa ADMa DEVa OUR IND UNI COM NAV INT STA PRE"', 'Status': '200 OK', 'X-Source': 'Pocket', 'Cache-Control': 'no-store, no-cache, must-revalidate, post-check=0, pre-check=0', 'X-Frame-Options': 'SAMEORIGIN', 'Pragma': 'no-cache', 'X-Limit-User-Remaining': '499', 'X-Limit-User-Reset': '3600', 'transfer-encoding': 'chunked', 'Connection': 'keep-alive', 'X-Limit-Key-Remaining': '9999', 'Content-Type': 'application/json', 'X-Limit-Key-Limit': '10000', 'X-Limit-User-Limit': '500', 'Server': 'Apache'})

# %% [markdown]
# # Traitement des données textuelles : expressions régulières

# %% [markdown]
# # Méthodes simples de classification automatique de documents : tf-idf

# %% [markdown]
# # Méthodes d'accélération de calcul : numba, cython

# %% [markdown]
# # Solutions de traitement de gros volumes de données: cytoolz, serialisation, dask

# %%
#Séance 5 : distinguer le type de texte en fonction des documents html => webscraping. API : créer sa propre api. A voir aussi : d'autres exemples d'API : se connecter à github. Se connecter à l'API SNCF. etc.'

# %%
#Séance 6 :
