# %% [markdown]
# # TD 3 - Mise en pratique des séances 1 et 2 - Utilisation de pandas et visualisation
#
# ## Exercice 1 - manipulation des bases
#
# Durée : 10 minutes
#
# 1) Importer la base de données relatives aux joueurs de la Coupe du Monde 2014
#
# 2) Déterminer le nombre de joueurs dans chaque équipe et créer un dictionnaire { équipe : Nombre de joueurs}
#
# 3) Déterminer quels sont les 3 joueurs qui ont couvert le plus de distance. Y a t il un biais de sélection ?
#
# 4) Parmis les joueurs qui sont dans le premier décile des joueurs plus rapides, qui a passé le plus clair de son temps à courrir sans la balle ?

# %%
# Import du fichier

# %%
import pandas as pd
data_players = pd.read_excel("./Python 2A Eco TD/TD3/Players_WC2014.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-3215ee85b59d> in <module>()
#       1 import pandas as pd
# ----> 2 data_players = pd.read_excel("./Python 2A Eco TD/TD3/Players_WC2014.xlsx")
#
# /home/atheane/anaconda3/lib/python3.6/site-packages/pandas/io/excel.py in read_excel(io, sheetname, header, skiprows, skip_footer, index_col, names, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, has_index_names, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     198
#     199     if not isinstance(io, ExcelFile):
# --> 200         io = ExcelFile(io, engine=engine)
#     201
#     202     return io._parse_excel(
#
# /home/atheane/anaconda3/lib/python3.6/site-packages/pandas/io/excel.py in __init__(self, io, **kwds)
#     255             self.book = xlrd.open_workbook(file_contents=data)
#     256         elif isinstance(io, compat.string_types):
# --> 257             self.book = xlrd.open_workbook(io)
#     258         else:
#     259             raise ValueError('Must explicitly set engine if not passing in'
#
# /home/atheane/anaconda3/lib/python3.6/site-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     393         peek = file_contents[:peeksz]
#     394     else:
# --> 395         with open(filename, "rb") as f:
#     396             peek = f.read(peeksz)
#     397     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: './Python 2A Eco TD/TD3/Players_WC2014.xlsx'

# %%
data_players.head()
# Out:
#   Clearance Rate Colors Distance Covered In Possession  \
# 0            NaN    NaN                            NaN
# 1            NaN    NaN                            NaN
# 2            NaN    NaN                            NaN
# 3            NaN    NaN                          2.1km
# 4              -    NaN                          5.0km
#
#   Distance Covered Not In Possession Distance Covered Location  \
# 0                                NaN              NaN  Algeria
# 1                                NaN              NaN  Algeria
# 2                                NaN              NaN  Algeria
# 3                              4.2km            8.7km  Algeria
# 4                             10.0km           20.6km  Algeria
#
#                   Name     Team Top Speed  % Passes Completed  Assists  \
# 0   Cedric SI MOHAMMED  Algeria       NaN                 NaN      NaN
# 1    Liassine CADAMURO  Algeria       NaN                 NaN      NaN
# 2  Mohamed ZEMMAMOUCHE  Algeria       NaN                 NaN      NaN
# 3         Riyad MAHREZ  Algeria  23.9km/h                0.55      NaN
# 4        Saphir TAIDER  Algeria  25.7km/h                0.74      NaN
#
#    Attempted Clearances  Attempts In The Area  Attempts Off-Target  \
# 0                   NaN                   NaN                  NaN
# 1                   NaN                   NaN                  NaN
# 2                   NaN                   NaN                  NaN
# 3                   NaN                   1.0                  1.0
# 4                   0.0                   NaN                  NaN
#
#    Attempts On Target  Attempts On-Target From Inside The Area  \
# 0                 NaN                                      NaN
# 1                 NaN                                      NaN
# 2                 NaN                                      NaN
# 3                 0.0                                      0.0
# 4                 NaN                                      NaN
#
#    Attempts On-Target From Outside The Area  Attempts Outside The Area
# 0                                       NaN                        NaN
# 1                                       NaN                        NaN
# 2                                       NaN                        NaN
# 3                                       0.0                        0.0
# 4                                       NaN                        NaN

# %% [markdown]
# ## Nombre de joueurs par équipe

# %%
data_players.groupby(['Team']).size().to_dict()
# Out:
# {'Algeria': 23,
#  'Argentina': 23,
#  'Australia': 23,
#  'Belgium': 23,
#  'Bosnia': 23,
#  'Brazil': 23,
#  'Cameroon': 23,
#  'Chile': 23,
#  'Colombia': 23,
#  'Costa Rica': 23,
#  'Croatia': 23,
#  "Côte d'Ivoire": 23,
#  'Ecuador': 22,
#  'England': 22,
#  'France': 22,
#  'Germany': 22,
#  'Ghana': 23,
#  'Greece': 23,
#  'Honduras': 23,
#  'Iran': 23,
#  'Italy': 23,
#  'Japan': 23,
#  'Korea Republic': 23,
#  'Mexico': 23,
#  'Netherlands': 23,
#  'Nigeria': 23,
#  'Portugal': 23,
#  'Russia': 23,
#  'Spain': 23,
#  'Switzerland': 23,
#  'USA': 23,
#  'Uruguay': 23}

# %% [markdown]
# ## Les joueurs ayant couvert le plus de distance

# %%
## quels joueurs ont couvert le plus de distance ? 
data_players['Distance Covered'] = data_players['Distance Covered'].str.replace('km','')

# %%
data_players['Distance Covered'] = data_players['Distance Covered'].convert_objects(convert_numeric=True)
data_players.sort_values(['Distance Covered'], ascending = 0).head(n=3)
# Out:
# C:\Users\Houston\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
#     Clearance Rate Colors Distance Covered In Possession  \
# 362              1  Top 4                         34.5km
# 353            0.5  Top 4                         34.3km
# 42               1  Top 4                         29.5km
#
#     Distance Covered Not In Possession  Distance Covered   Location  \
# 362                             26.4km              84.0    Germany
# 353                             28.0km              82.6    Germany
# 42                              30.7km              81.2  Argentina
#
#                   Name       Team Top Speed  % Passes Completed  Assists  \
# 362     Thomas MUELLER    Germany  30.5km/h                0.69      3.0
# 353         Toni KROOS    Germany  29.8km/h                0.85      4.0
# 42   Javier MASCHERANO  Argentina  30.3km/h                0.86      NaN
#
#      Attempted Clearances  Attempts In The Area  Attempts Off-Target  \
# 362                   3.0                  12.0                  6.0
# 353                   2.0                   2.0                  5.0
# 42                    8.0                   0.0                  0.0
#
#      Attempts On Target  Attempts On-Target From Inside The Area  \
# 362                10.0                                      7.0
# 353                11.0                                      2.0
# 42                  4.0                                      0.0
#
#      Attempts On-Target From Outside The Area  Attempts Outside The Area
# 362                                       3.0                        4.0
# 353                                       9.0                       14.0
# 42                                        4.0                        4.0

# %% [markdown]
# On voit un clair effet de sélection sur cette variable : ce sont les joueurs dont les équipes ont été le plus loin dans la compétition qui couvert le plus de distance.

# %% [markdown]
# ## Qui a été le plus efficace ?
#
# On a besoin de rendre la variable Top Speed numérique, et de créer une nouvelle variable avec le poucentage de possession de balle

# %%
## Qui a été le plus rapide ?

data_players['Top Speed'] = data_players['Top Speed'].str.replace('km/h','')
data_players['Top Speed'] = data_players['Top Speed'].convert_objects(convert_numeric=True)
data_players.sort_values(['Top Speed'], ascending = 0).head(n=3)
# Out:
# C:\Users\Houston\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   after removing the cwd from sys.path.
#     Clearance Rate          Colors Distance Covered In Possession  \
# 222           0.89  Quarter Finals                         15.4km
# 247           0.75     Group Stage                         10.5km
# 32             0.5           Top 4                         25.1km
#
#     Distance Covered Not In Possession  Distance Covered       Location  \
# 222                             22.7km              56.2     Costa Rica
# 247                              9.3km              28.8  Côte d'Ivoire
# 32                              19.2km              63.6      Argentina
#
#                 Name           Team  Top Speed  % Passes Completed  Assists  \
# 222      Junior DIAZ     Costa Rica       33.8                0.65      NaN
# 247     Serge AURIER  Côte d'Ivoire       33.5                0.73      NaN
# 32   Gonzalo HIGUAIN      Argentina       33.1                0.75      1.0
#
#      Attempted Clearances  Attempts In The Area  Attempts Off-Target  \
# 222                   9.0                   NaN                  NaN
# 247                   4.0                   2.0                  0.0
# 32                    4.0                  11.0                  7.0
#
#      Attempts On Target  Attempts On-Target From Inside The Area  \
# 222                 NaN                                      NaN
# 247                 3.0                                      2.0
# 32                  6.0                                      6.0
#
#      Attempts On-Target From Outside The Area  Attempts Outside The Area
# 222                                       NaN                        NaN
# 247                                       1.0                        1.0
# 32                                        0.0                        2.0

# %%
## Parmis ceux qui sont dans le décile des plus rapides, qui a passé le plus clair de son temps à courrir sans la balle ?
data_players['Distance Covered In Possession'] = data_players['Distance Covered In Possession'].str.replace('km','')
data_players['Distance Covered In Possession'] = data_players['Distance Covered In Possession'].convert_objects(convert_numeric=True)
data_players['Share of Possession'] = data_players['Distance Covered In Possession']/data_players['Distance Covered']
# Out:
# C:\Users\Houston\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data_players[data_players['Top Speed'] > data_players['Top Speed'].
             quantile(.90)].sort_values(['Share of Possession'], ascending = 0).head()
# Out:
#     Clearance Rate       Colors  Distance Covered In Possession  \
# 363              1  Group Stage                             6.4
# 102              -          NaN                             4.7
# 472              -  Group Stage                             9.0
# 351              -        Top 4                            31.6
# 646            NaN  Group Stage                            13.7
#
#     Distance Covered Not In Possession  Distance Covered Location  \
# 363                              4.2km              14.6  Germany
# 102                              3.0km              10.8   Bosnia
# 472                              6.0km              20.8    Italy
# 351                             23.6km              73.2  Germany
# 646                             10.4km              31.8    Spain
#
#                  Name     Team  Top Speed  % Passes Completed  Assists  \
# 363  Shkodran MUSTAFI  Germany       32.9                0.80      NaN
# 102  Avdija VRSAJEVIC   Bosnia       32.1                0.75      0.0
# 472   Mario BALOTELLI    Italy       33.0                0.65      0.0
# 351       Mesut OEZIL  Germany       32.0                0.79      1.0
# 646        Jordi ALBA    Spain       31.6                0.82      NaN
#
#      Attempted Clearances  Attempts In The Area  Attempts Off-Target  \
# 363                   1.0                   1.0                  0.0
# 102                   0.0                   2.0                  1.0
# 472                   0.0                   3.0                  3.0
# 351                   0.0                   8.0                  3.0
# 646                   NaN                   2.0                  2.0
#
#      Attempts On Target  Attempts On-Target From Inside The Area  \
# 363                 1.0                                      1.0
# 102                 1.0                                      1.0
# 472                 4.0                                      2.0
# 351                 7.0                                      6.0
# 646                 1.0                                      1.0
#
#      Attempts On-Target From Outside The Area  Attempts Outside The Area  \
# 363                                       0.0                        0.0
# 102                                       0.0                        0.0
# 472                                       2.0                        4.0
# 351                                       1.0                        2.0
# 646                                       0.0                        1.0
#
#      Share of Possession
# 363             0.438356
# 102             0.435185
# 472             0.432692
# 351             0.431694
# 646             0.430818
